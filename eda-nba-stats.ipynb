# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv("nba-full.csv")

# %%
df.head(10)
# Out:
#       #                 PLAYER TEAM    GP   MIN   PTS   FGM   FGA   FG%  3PM  \
# 0   1.0          Stephen Curry  GSW  63.0  34.2  32.0  10.4  21.7  48.2  5.3
# 1   2.0           Bradley Beal  WAS  60.0  35.8  31.3  11.2  23.0  48.5  2.2
# 2   3.0         Damian Lillard  POR  67.0  35.8  28.8   9.0  19.9  45.1  4.1
# 3   4.0            Joel Embiid  PHI  51.0  31.1  28.5   9.0  17.6  51.3  1.1
# 4   5.0  Giannis Antetokounmpo  MIL  61.0  33.0  28.1  10.3  18.0  56.9  1.1
# 5   6.0            Luka Doncic  DAL  66.0  34.3  27.7   9.8  20.5  47.9  2.9
# 6   7.0            Zach LaVine  CHI  58.0  35.1  27.4   9.8  19.4  50.7  3.4
# 7   8.0        Zion Williamson  NOP  61.0  33.2  27.0  10.4  17.0  61.1  0.2
# 8   9.0           Kyrie Irving  BKN  54.0  34.9  26.9  10.2  20.1  50.6  2.8
# 9  10.0           Jayson Tatum  BOS  64.0  35.8  26.4   9.5  20.6  45.9  2.9
#
#    ...   FT%  OREB  DREB   REB  AST  STL  BLK  TOV   EFF   SEASON
# ...

# %%
df.shape
# Out:
# (710, 24)

# %%
df.describe()
# Out:
#                 #          GP         MIN         PTS         FGM         FGA  \
# count  710.000000  710.000000  710.000000  710.000000  710.000000  710.000000
# mean   118.929577   67.085915   25.712958   12.276901    4.496056    9.539718
# std     68.540070    7.523893    6.688019    6.286601    2.210900    4.626471
# min      1.000000   51.000000    9.600000    1.900000    0.600000    1.800000
# 25%     60.000000   62.000000   20.125000    7.600000    2.825000    6.000000
# 50%    119.000000   67.000000   26.100000   10.450000    3.900000    8.300000
# 75%    178.000000   72.750000   31.300000   15.675000    5.800000   12.500000
# max    245.000000   83.000000   37.900000   33.100000   11.200000   23.000000
#
#               FG%         3PM         3PA         3P%  ...         FTA  \
# count  710.000000  710.000000  710.000000  710.000000  ...  710.000000
# mean    47.568169    1.371268    3.755634   33.535070  ...    2.439296
# ...

# %%
df.isnull().sum()
# Out:
# #         0
# PLAYER    0
# TEAM      0
# GP        0
# MIN       0
# PTS       0
# FGM       0
# FGA       0
# FG%       0
# 3PM       0
# 3PA       0
# 3P%       0
# FTM       0
# FTA       0
# FT%       0
# OREB      0
# DREB      0
# REB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# EFF       0
# SEASON    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# #         0
# PLAYER    0
# TEAM      0
# GP        0
# MIN       0
# PTS       0
# FGM       0
# FGA       0
# FG%       0
# 3PM       0
# 3PA       0
# 3P%       0
# FTM       0
# FTA       0
# FT%       0
# OREB      0
# DREB      0
# REB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# EFF       0
# SEASON    0
# dtype: int64

# %%
#histogram of top scores
hist = df["PTS"]

plt.hist(hist, bins=np.arange(40), alpha=1)
plt.grid(True)
plt.title("Histogram Of The Scores Within The Season")
plt.xlabel('Points')
# Out:
# Text(0.5, 0, 'Points')

# %%
#histogram of top scores
hist = df["AST"]

plt.hist(hist, bins=25, alpha=1)
plt.grid(True)
plt.title("Histogram Of Number Of Assists")
plt.xlabel('Assists')
# Out:
# Text(0.5, 0, 'Assists')

# %%
#histogram of blocks

hist=df["BLK"]

plt.hist(hist, bins=30, alpha=1)
plt.grid(True)
plt.title("Histogram Of Number Of Blocks")
plt.xlabel('Blocks')
# Out:
# Text(0.5, 0, 'Blocks')

# %%
#box plot free throwsmade

plt.figure(figsize=(14, 4))
plt.subplot(1, 5, 4)
sns.boxplot(y=df['FTM'],data =df, color='green')
plt.title('Box Plot Of Free Throwsmade')
# Out:
# Text(0.5, 1.0, 'Box Plot Of Free Throwsmade')

# %%
name_of_player = df.loc[df['PTS'].idxmax(), 'PLAYER']
name_of_player

top_points = df.nlargest(10,'PTS')

plt.bar(top_points['PLAYER'], top_points['PTS'])
plt.bar(name_of_player, df.loc[df['PLAYER'] == name_of_player, 'PTS'])
plt.xlabel('Player Name')
plt.ylabel('Points')
plt.title('Top 10 Scorers ')
plt.xticks(rotation=45, ha="right") 
plt.show()

# %%
#team performance stats for rebounds mean
team_performance = df.groupby('TEAM'). agg({'REB':['mean']}).reset_index()
plt.bar(team_performance['TEAM'], team_performance['REB']['mean'], width=0.5)
plt.xticks(rotation=45, ha="right") 

plt.xlabel('Team Name')
plt.ylabel('No Of Rebounds')
plt.title('Teams And Their Rebounds')
plt.show()

# %%
#leading teams and their number of 3 points made
team_performance = df.groupby('TEAM'). agg({'3PM':['mean']}).reset_index()
plt.bar(team_performance['TEAM'], team_performance['3PM']['mean'], width=0.5)
plt.xticks(rotation=45, ha="right") 

plt.xlabel('Team Name')
plt.ylabel('No Of 3 Points')
plt.title('Teams And Average 3 Points Made')
plt.show()

# %%
#correlation between key performace 
df2=df[['REB','AST','STL','BLK', 'TOV']]

correlation = df2.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Of Performance Metrics')
plt.show()

# %%
#scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='FTM', y='FTA', data=df, alpha=0.5)
plt.title('FTM vs. FTA')
plt.xlabel('FTM')
plt.ylabel('FTA')
plt.show()

# %%
#scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='DREB', y='OREB', data=df, alpha=0.5)
plt.title('DREB vs. OREB')
plt.xlabel('OREB')
plt.ylabel('DREB')
plt.show()

# %%
# Countplot for categorical variables how many players are on the team
sns.countplot(x='TEAM', data=df)
plt.xticks(rotation=90)
plt.title('Count Of Players By Team')
plt.show()

# %%
sns.pairplot(df[['PTS','FGM','FGA','3PM','3PA']])
plt.show()

# %%
#season and points
team_performance = df.groupby('SEASON'). agg({'PTS':['sum']}).reset_index()
plt.bar(team_performance['SEASON'], team_performance['PTS']['sum'], width=0.5)
plt.xticks(rotation=45, ha="right") 

plt.xlabel('Season')
plt.ylabel('Points Made')
plt.title('Points By Year')
plt.show()
